# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('out.csv')

fig = px.line(df, x = 'x', y = 'y', title='graph')
fig.show()
# Out:
# <div>
#
#
#             <div id="22f8b5e1-03d0-4704-8823-230667aff253" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("22f8b5e1-03d0-4704-8823-230667aff253")) {
#                     Plotly.newPlot(
#                         '22f8b5e1-03d0-4704-8823-230667aff253',
# ...
